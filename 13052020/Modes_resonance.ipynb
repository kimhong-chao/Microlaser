# %%
# %matplotlib notebook
import meep as mp
import matplotlib.pyplot as plt
import numpy as np

# %%
path = "/home/hong/Desktop/Microlaser1/data/"
npzfile1 = np.load(path + 'modes_Ez_odd.npz')
npzfile2 = np.load(path + 'modes_Ez_even.npz')
npzfile3 = np.load(path + 'modes_Ez_mixed.npz')

modes_odd = npzfile1['arr_0']
modes_even = npzfile2['arr_0']
modes_mixed = npzfile3['arr_0']

plt.figure()
plt.scatter(2*np.pi*modes_odd[:,1], -2*np.pi*modes_odd[:,1]/2/modes_odd[:,0])
plt.scatter(2*np.pi*modes_even[:,1], -2*np.pi*modes_even[:,1]/2/modes_even[:,0], c='red')
plt.scatter(2*np.pi*modes_mixed[:,1], -2*np.pi*modes_mixed[:,1]/2/modes_mixed[:,0], c='green')


plt.xlabel('$2\pi \omega_n$')
plt.ylabel('$Im(-2 \pi \omega_n)$')
plt.grid()
plt.title('modes de résonance')
# Out:
# <img src="data:image/png;base64,..." width="640">
# Text(0.5, 1.0, 'modes de résonance')
