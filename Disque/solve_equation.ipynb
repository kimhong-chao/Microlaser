# %%
# %matplotlib notebook
import numpy as np
import matplotlib.pyplot as plt
import scipy 
import scipy.optimize as op
import scipy.special as sp
from matplotlib import cm
from matplotlib.ticker import LinearLocator, FormatStrFormatter
from mpl_toolkits.mplot3d import Axes3D

# %%
def func(k, index, r, m) :
    return  np.abs(index*sp.jvp(m, index*k*r)/sp.jv(m, index*k*r)) - np.abs(sp.h1vp(m,k*r)/sp.hankel1(m,k*r))

# %%
fig = plt.figure(dpi=150)
ax = fig.add_subplot(111, projection='3d')

# Make data
u = np.linspace(0, 20, 500)
v = np.linspace(-1, 1 ,100)
X, Y = np.meshgrid(u, v)
# Plot the surface
surf = ax.plot_surface(X, Y, func(X+Y*1j,1.5,1,5), cmap=cm.coolwarm,
                       linewidth=0, antialiased=False)
ax.set_zlim(-5, 100.01)
ax.zaxis.set_major_locator(LinearLocator(20))
ax.zaxis.set_major_formatter(FormatStrFormatter('%.01f'))
fig.colorbar(surf, shrink=0.5, aspect=5)
ax.set_title('3D Plot of func $norm(left) - norm(right)$')
ax.set_xlabel('$Re(kR)$')
ax.set_ylabel('$Im(kR)$')
ax.set_zlabel('$norm(left) - norm(right)$')
plt.show()
plt.savefig('abs_func_en3D')
# Out:
# <img src="data:image/png;base64,..." width="960">

# %%
u = np.linspace(0, 20, 500)
v = np.linspace(-1, 1 ,100)
X, Y = np.meshgrid(u, v)

plt.figure()
CS = plt.contour(X, Y, func(X+Y*1j,1.5,1,5), [0])
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
u = np.linspace(0, 20, 500)
v = np.linspace(-1, 1 ,100)
X, Y = np.meshgrid(u, v)

fig = plt.figure(dpi=150)
cp = plt.contourf(X, Y, func(X+Y*1j,1.5,1,5))
fig.colorbar(cp)
plt.title('Contours Plot $norm(left) - norm(right)$')
plt.xlabel('$Re(kR)$')
plt.ylabel('$Im(kR)$')
plt.show()
plt.savefig('abs_func_contourf')
# Out:
# <img src="data:image/png;base64,..." width="960">

# %%
u = np.linspace(0, 20, 500)
v = np.linspace(-1, 1 ,100)
X, Y = np.meshgrid(u, v)

fig = plt.figure()
cp = plt.contourf(X, Y, func(X+Y*1j,1.5,1,3))
fig.colorbar(cp)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
def func_(k, index, r, m) :
    return  np.abs(index*sp.jvp(m, index*k*r)/sp.jv(m, index*k*r) - sp.h1vp(m,k*r)/sp.hankel1(m,k*r))

# %%
u = np.linspace(17.5, 20, 700)
v = np.linspace(-1, 1 ,200)
X, Y = np.meshgrid(u, v)

fig = plt.figure()
cp = plt.contourf(X, Y, func_(X+Y*1j,1.5,1,5))
fig.colorbar(cp)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
fig = plt.figure(dpi=150)
ax = fig.add_subplot(111, projection='3d')

# Make data
u = np.linspace(0, 20, 100)
v = np.linspace(-1, 1 ,100)
X, Y = np.meshgrid(u, v)
# Plot the surface
surf = ax.plot_surface(X, Y, func_(X+Y*1j,1.5,1,5), cmap=cm.coolwarm,
                       linewidth=0, antialiased=False)
ax.set_zlim(1, 100.01)
ax.zaxis.set_major_locator(LinearLocator(20))
ax.zaxis.set_major_formatter(FormatStrFormatter('%.01f'))
fig.colorbar(surf, shrink=0.5, aspect=5)
ax.set_title('3D Plot of func_ $norm(left - right)$')
ax.set_xlabel('$Re(kR)$')
ax.set_ylabel('$Im(kR)$')
ax.set_zlabel('$norm(left - right)$')
plt.show()
plt.savefig('abs_func__en3D')
# Out:
# <img src="data:image/png;base64,..." width="960">
